# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from pathlib import Path

# %%
directorio_actual = Path.cwd()
ruta_base = directorio_actual.parent
    
    # Cargar los datos
ruta_datos = ruta_base / 'data' / 'gym_churn_us.csv'
df = pd.read_csv(ruta_datos) 
caida_frecuencia = df['Avg_class_frequency_total'] - df['Avg_class_frequency_current_month']
df['caida_frecuencia'] = caida_frecuencia
X = df.drop(columns=['Churn', 'Avg_class_frequency_total', 'Phone', 'gender'])
y = df['Churn']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       2 ruta_base = directorio_actual.parent
#       3
#       4     # Cargar los datos
#       5 ruta_datos = ruta_base / 'data' / 'gym_churn_us.csv'
# ----> 6 caida_frecuencia = df['Avg_class_frequency_total'] - df['Avg_class_frequency_current_month']
#       7 df['caida_frecuencia'] = caida_frecuencia
#       8 X = df.drop(columns=['Churn', 'Avg_class_frequency_total', 'Phone', 'gender'])
#       9 y = df['Churn']
#
# NameError: name 'df' is not defined
